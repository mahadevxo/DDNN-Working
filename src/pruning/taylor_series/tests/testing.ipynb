# %%
import torch
from torchvision import models as models
import numpy as np
import gc
import time
import glob
from torchvision import transforms, datasets
import random
from torch.utils.data import DataLoader, Subset

# %%
def clear_memory():
    gc.collect()
    if torch.cuda.is_available():
        torch.cuda.empty_cache()
    elif torch.backends.mps.is_available():
        torch.mps.empty_cache()

# %%
def create_results_file(filename=f'pruning_results_{time.time()}.csv'):
    with open(filename, 'w') as f:
        f.write("Pruning Amount, Final Accuracy, Time, Memory\n")
    return filename

# %%
def append_result(filename, pruning_amount, accuracy, compute_time, model_size):
    with open(filename, 'a') as f:
        f.write(f"{pruning_amount}%, {accuracy}%,{compute_time}, {model_size}\n")

# %%
model_paths = glob.glob("AlexNetPruned/*")
model_paths.sort()

# %%
def get_images(folder_path='imagenet-mini/train', num_samples=200):
    transform = transforms.Compose([
        transforms.Resize((224,224)),
        transforms.RandomHorizontalFlip(), 
        transforms.RandomRotation(15),
        transforms.ToTensor(),
        transforms.Normalize(mean=[0.485, 0.456, 0.406], 
                            std=[0.229, 0.224, 0.225]),
    ])
    data_dataset = datasets.ImageFolder(folder_path, transform=transform)
    indices = random.sample(range(len(data_dataset)), min(num_samples, len(data_dataset)))
    data_dataset = Subset(data_dataset, indices)
    
    return DataLoader(data_dataset, batch_size=32, shuffle=True, num_workers=1, pin_memory=True)

# %%
def test(model, test_loader, device, final_test=True):
    model.eval()
    model.to(device)
    correct_top1 = 0
    total = 0
    compute_time = 0
    accuracies = []
    computation_times = []
    
    tries = 3 if final_test else 1
    for _ in range(tries):        
        with torch.inference_mode():
            for images, labels in test_loader:
                try:
                    images = images.to(device, non_blocking=True)
                    labels = labels.to(device, non_blocking=True)
                    
                    t1 = time.time()
                    outputs = model(images)
                    t2 = time.time()
                    compute_time += t2 - t1
                    
                    # Top-1 accuracy
                    _, predicted = torch.max(outputs, 1)
                    total += labels.size(0)
                    correct_top1 += (predicted == labels).sum().item()
                    
                finally:
                    # Free up memory
                    del images, labels
                    if 'outputs' in locals(): 
                        del outputs
                    if 'predicted' in locals(): 
                        del predicted
                    clear_memory()
        
        accuracies.append(100.0 * correct_top1 / total if total > 0 else 0)
        computation_times.append(compute_time)
        clear_memory()
    del test_loader
    clear_memory()
    
    return [np.mean(accuracies), min(computation_times)]

# %%
def get_model_size(model):
    total_size = sum(
        param.nelement() * param.element_size() for param in model.parameters()
    )
    # Convert to MB
    return total_size / (1024 ** 2)

# %%
print(model_paths)
# Out:
# ['AlexNetPruned/pruned_AlexNet_00.00.pth', 'AlexNetPruned/pruned_AlexNet_00.50.pth', 'AlexNetPruned/pruned_AlexNet_01.00.pth', 'AlexNetPruned/pruned_AlexNet_01.50.pth', 'AlexNetPruned/pruned_AlexNet_02.00.pth', 'AlexNetPruned/pruned_AlexNet_02.50.pth', 'AlexNetPruned/pruned_AlexNet_03.00.pth', 'AlexNetPruned/pruned_AlexNet_03.50.pth', 'AlexNetPruned/pruned_AlexNet_04.00.pth', 'AlexNetPruned/pruned_AlexNet_04.50.pth', 'AlexNetPruned/pruned_AlexNet_05.00.pth', 'AlexNetPruned/pruned_AlexNet_05.50.pth', 'AlexNetPruned/pruned_AlexNet_06.00.pth', 'AlexNetPruned/pruned_AlexNet_06.50.pth', 'AlexNetPruned/pruned_AlexNet_07.00.pth', 'AlexNetPruned/pruned_AlexNet_07.50.pth', 'AlexNetPruned/pruned_AlexNet_08.00.pth', 'AlexNetPruned/pruned_AlexNet_08.50.pth', 'AlexNetPruned/pruned_AlexNet_09.00.pth', 'AlexNetPruned/pruned_AlexNet_09.50.pth', 'AlexNetPruned/pruned_AlexNet_10.00.pth', 'AlexNetPruned/pruned_AlexNet_10.50.pth', 'AlexNetPruned/pruned_AlexNet_11.00.pth', 'AlexNetPruned/pruned_AlexNet_11.50.pth', 'AlexNetPruned/pruned_AlexNet_12.00.pth', 'AlexNetPruned/pruned_AlexNet_12.50.pth', 'AlexNetPruned/pruned_AlexNet_13.00.pth', 'AlexNetPruned/pruned_AlexNet_13.50.pth', 'AlexNetPruned/pruned_AlexNet_14.00.pth', 'AlexNetPruned/pruned_AlexNet_14.50.pth', 'AlexNetPruned/pruned_AlexNet_15.00.pth', 'AlexNetPruned/pruned_AlexNet_15.50.pth', 'AlexNetPruned/pruned_AlexNet_16.00.pth', 'AlexNetPruned/pruned_AlexNet_16.50.pth', 'AlexNetPruned/pruned_AlexNet_17.00.pth', 'AlexNetPruned/pruned_AlexNet_17.50.pth', 'AlexNetPruned/pruned_AlexNet_18.00.pth', 'AlexNetPruned/pruned_AlexNet_18.50.pth', 'AlexNetPruned/pruned_AlexNet_19.00.pth', 'AlexNetPruned/pruned_AlexNet_19.50.pth', 'AlexNetPruned/pruned_AlexNet_20.00.pth', 'AlexNetPruned/pruned_AlexNet_20.50.pth', 'AlexNetPruned/pruned_AlexNet_21.00.pth', 'AlexNetPruned/pruned_AlexNet_21.50.pth', 'AlexNetPruned/pruned_AlexNet_22.00.pth', 'AlexNetPruned/pruned_AlexNet_22.50.pth', 'AlexNetPruned/pruned_AlexNet_23.00.pth', 'AlexNetPruned/pruned_AlexNet_23.50.pth', 'AlexNetPruned/pruned_AlexNet_24.00.pth', 'AlexNetPruned/pruned_AlexNet_24.50.pth', 'AlexNetPruned/pruned_AlexNet_25.00.pth', 'AlexNetPruned/pruned_AlexNet_25.50.pth', 'AlexNetPruned/pruned_AlexNet_26.00.pth', 'AlexNetPruned/pruned_AlexNet_26.50.pth', 'AlexNetPruned/pruned_AlexNet_27.00.pth', 'AlexNetPruned/pruned_AlexNet_27.50.pth', 'AlexNetPruned/pruned_AlexNet_28.00.pth', 'AlexNetPruned/pruned_AlexNet_28.50.pth', 'AlexNetPruned/pruned_AlexNet_29.00.pth', 'AlexNetPruned/pruned_AlexNet_29.50.pth', 'AlexNetPruned/pruned_AlexNet_30.00.pth', 'AlexNetPruned/pruned_AlexNet_30.50.pth', 'AlexNetPruned/pruned_AlexNet_31.00.pth', 'AlexNetPruned/pruned_AlexNet_31.50.pth', 'AlexNetPruned/pruned_AlexNet_32.00.pth', 'AlexNetPruned/pruned_AlexNet_32.50.pth', 'AlexNetPruned/pruned_AlexNet_33.00.pth', 'AlexNetPruned/pruned_AlexNet_33.50.pth', 'AlexNetPruned/pruned_AlexNet_34.00.pth', 'AlexNetPruned/pruned_AlexNet_34.50.pth', 'AlexNetPruned/pruned_AlexNet_35.00.pth', 'AlexNetPruned/pruned_AlexNet_35.50.pth', 'AlexNetPruned/pruned_AlexNet_36.00.pth', 'AlexNetPruned/pruned_AlexNet_36.50.pth', 'AlexNetPruned/pruned_AlexNet_37.00.pth', 'AlexNetPruned/pruned_AlexNet_37.50.pth', 'AlexNetPruned/pruned_AlexNet_38.00.pth', 'AlexNetPruned/pruned_AlexNet_38.50.pth', 'AlexNetPruned/pruned_AlexNet_39.00.pth', 'AlexNetPruned/pruned_AlexNet_39.50.pth', 'AlexNetPruned/pruned_AlexNet_40.00.pth', 'AlexNetPruned/pruned_AlexNet_40.50.pth', 'AlexNetPruned/pruned_AlexNet_41.00.pth', 'AlexNetPruned/pruned_AlexNet_41.50.pth', 'AlexNetPruned/pruned_AlexNet_42.00.pth', 'AlexNetPruned/pruned_AlexNet_42.50.pth', 'AlexNetPruned/pruned_AlexNet_43.00.pth', 'AlexNetPruned/pruned_AlexNet_43.50.pth', 'AlexNetPruned/pruned_AlexNet_44.00.pth', 'AlexNetPruned/pruned_AlexNet_44.50.pth', 'AlexNetPruned/pruned_AlexNet_45.00.pth', 'AlexNetPruned/pruned_AlexNet_45.50.pth', 'AlexNetPruned/pruned_AlexNet_46.00.pth', 'AlexNetPruned/pruned_AlexNet_46.50.pth', 'AlexNetPruned/pruned_AlexNet_47.00.pth', 'AlexNetP ...

# %%
filename = create_results_file(input("Enter filename for results: ")+".csv")

# device = torch.device("cuda" if torch.cuda.is_available() else "mps" if torch.backends.mps.is_available() else "cpu")
device = 'cpu'
print(f"Using device: {device}")


# Create a test dataset
test_loader = get_images()

for model_path in model_paths:
    pruning_amount = model_path.split('_')[-1].replace('.pth', '')
    print(f"Testing model with pruning amount {pruning_amount}%")
    
    # Load the pruned model
    model = torch.load(model_path, weights_only=False, map_location=device)
    
    # Get the size of the model
    model_size = get_model_size(model)
    
    # Test the model
    accuracy, compute_time = test(model, test_loader, device, final_test=True)
    
    pruning_amount = str(model_path.split('_')[-1].split('.')[0]) + '.' + str(model_path.split('_')[-1].split('.')[1])
    
    print(f"Pruning Amount: {pruning_amount}%")
    # Append results to file
    append_result(filename, pruning_amount, accuracy, compute_time, model_size)
    print(f"Model size: {model_size:.2f} MB")
    print(f"Final accuracy: {accuracy:.2f}%")
    print(f"Compute time: {compute_time:.5f} seconds")
    clear_memory()
    del model
    clear_memory()
    print("Memory cleared.")
    print("========================================")
# Out:
# Using device: cpu
# Testing model with pruning amount 0.00%
# Pruning Amount: 0.00%
# Model size: 233.08 MB
# Final accuracy: 54.31%
# Compute time: 1.06045 seconds
# Memory cleared.
# ========================================
# Testing model with pruning amount 0.50%
# Pruning Amount: 0.50%
# Model size: 232.44 MB
# Final accuracy: 56.67%
# Compute time: 0.95516 seconds
# Memory cleared.
# ========================================
# Testing model with pruning amount 1.00%
# Pruning Amount: 1.00%
# Model size: 231.75 MB
# Final accuracy: 50.42%
# Compute time: 0.94975 seconds
# Memory cleared.
# ========================================
# Testing model with pruning amount 1.50%
# Pruning Amount: 1.50%
# Model size: 229.98 MB
# Final accuracy: 58.69%
# Compute time: 0.94410 seconds
# Memory cleared.
# ========================================
# Testing model with pruning amount 10.00%
# Pruning Amount: 10.00%
# Model size: 219.49 MB
# Final accuracy: 49.72%
# Compute time: 0.90458 seconds
# Memory cleared.
# ========================================
# Testing model with pruning amount 10.50%
# Pruning Amount: 10.50%
# Model size: 217.78 MB
# Final accuracy: 53.56%
# Compute time: 0.89823 seconds
# Memory cleared.
# ========================================
# Testing model with pruning amount 11.00%
# Pruning Amount: 11.00%
# Model size: 216.52 MB
# Final accuracy: 48.75%
# Compute time: 0.86880 seconds
# Memory cleared.
# ========================================
# Testing model with pruning amount 11.50%
# Pruning Amount: 11.50%
# Model size: 220.85 MB
# Final accuracy: 50.86%
# Compute time: 0.87748 seconds
# Memory cleared.
# ========================================
# Testing model with pruning amount 12.00%
# Pruning Amount: 12.00%
# Model size: 213.57 MB
# Final accuracy: 42.78%
# Compute time: 0.87818 seconds
# Memory cleared.
# ========================================
# Testing model with pruning amount 12.50%
# Pruning Amount: 12.50%
# Model size: 216.85 MB
# Final accuracy: 48.89%
# Compute time: 0.93205 seconds
# Memory cleared.
# ========================================
# Testing model with pruning amount 13.00%
# Pruning Amount: 13.00%
# Model size: 209.53 MB
# Final accuracy: 47.44%
# Compute time: 0.90209 seconds
# Memory cleared.
# ========================================
# Testing model with pruning amount 13.50%
# Pruning Amount: 13.50%
# Model size: 212.75 MB
# Final accuracy: 44.81%
# Compute time: 0.88069 seconds
# Memory cleared.
# ========================================
# Testing model with pruning amount 14.00%
# Pruning Amount: 14.00%
# Model size: 208.24 MB
# Final accuracy: 50.36%
# Compute time: 0.91171 seconds
# Memory cleared.
# ========================================
# Testing model with pruning amount 14.50%
# Pruning Amount: 14.50%
# Model size: 209.82 MB
# Final accuracy: 41.50%
# Compute time: 0.87998 seconds
# Memory cleared.
# ========================================
# Testing model with pruning amount 15.00%
# Pruning Amount: 15.00%
# Model size: 213.03 MB
# Final accuracy: 46.83%
# Compute time: 0.94874 seconds
# Memory cleared.
# ========================================
# Testing model with pruning amount 15.50%
# Pruning Amount: 15.50%
# Model size: 212.44 MB
# Final accuracy: 45.31%
# Compute time: 0.91962 seconds
# Memory cleared.
# ========================================
# Testing model with pruning amount 16.00%
# Pruning Amount: 16.00%
# Model size: 213.43 MB
# Final accuracy: 52.61%
# Compute time: 0.91778 seconds
# Memory cleared.
# ========================================
# Testing model with pruning amount 16.50%
# Pruning Amount: 16.50%
# Model size: 209.46 MB
# Final accuracy: 48.56%
# Compute time: 0.88066 seconds
# Memory cleared.
# ========================================
# Testing model with pruning amount 17.00%
# Pruning Amount: 17.00%
# Model size: 208.29 MB
# Final accuracy: 44.11%
# Compute time: 0.89004 seconds
# Memory cleared.
# ========================================
# Testing model with pruning amount 17.50%
# Pruning Amount: 17.50%
# Model size: 209.27 MB
# Final accuracy: 41.56%
# Compute time: 0.94206 seconds
# Memory cleared.
# ========================================
# Testing model with pruning amount 18.00%
# Pruning Amount: 18.00%
# Model size: 209.17 MB
# Final accuracy: 47.92%
# Compute time: 0.87871 seconds
# Memory cleared.
# ========================================
# Testing model with pruning amount 18.50%
# Pruning Amount: 18.50%
# Model size: 202.96 MB
# Final accuracy: 41.22%
# Compute time: 0.87157 seconds
# Memory cleared.
# ========================================
# Testing model with pruning amount 19.00%
# Pruning Amount: 19.00%
# Model size: 211.26 MB
# Final accuracy: 44.17%
# Compute time: 0.90561 seconds
# Memory cleared.
# ========================================
# Testing model with pruning amount 19.50%
# Pruning Amount: 19.50%
# Model size: 203.96 MB
# Final accuracy: 41.31%
# Compute time: 0.85672 seconds
# Memory cleared.
# ========================================
# Testing model with pruning amount 2.00%
# Pruning Amount: 2.00%
# Model size: 230.46 MB
# Final accuracy: 59.78%
# Compute time: 0.95150 seconds
# Memory cleared.
# ========================================
# Testing model with pruning amount 2.50%
# Pruning Amount: 2.50%
# Model size: 229.81 MB
# Final accuracy: 53.92%
# Compute time: 0.95278 seconds
# Memory cleared.
# ========================================
# Testing model with pruning amount 20.00%
# Pruning Amount: 20.00%
# Model size: 203.28 MB
# Final accuracy: 47.33%
# Compute time: 0.86787 seconds
# Memory cleared.
# ========================================
# Testing model with pruning amount 20.50%
# Pruning Amount: 20.50%
# Model size: 206.00 MB
# Final accuracy: 38.94%
# Compute time: 0.84891 seconds
# Memory cleared.
# ========================================
# Testing model with pruning amount 21.00%
# Pruning Amount: 21.00%
# Model size: 198.71 MB
# Final accuracy: 37.78%
# Compute time: 0.84578 seconds
# Memory cleared.
# ========================================
# Testing model with pruning amount 21.50%
# Pruning Amount: 21.50%
# Model size: 203.05 MB
# Final accuracy: 42.17%
# Compute time: 0.87142 seconds
# Memory cleared.
# ========================================
# Testing model with pruning amount 22.00%
# Pruning Amount: 22.00%
# Model size: 202.98 MB
# Final accuracy: 41.11%
# Compute time: 0.85523 seconds
# Memory cleared.
# ========================================
# Testing model with pruning amount 22.50%
# Pruning Amount: 22.50%
# Model size: 193.98 MB
# Final accuracy: 39.78%
# Compute time: 0.86061 seconds
# Memory cleared.
# ========================================
# Testing model with pruning amount 23.00%
# Pruning Amount: 23.00%
# Model size: 198.91 MB
# Final accuracy: 44.47%
# Compute time: 0.83623 seconds
# Memory cleared.
# ========================================
# Testing model with pruning amount 23.50%
# Pruning Amount: 23.50%
# Model size: 197.77 MB
# Final accuracy: 35.31%
# Compute time: 0.86541 seconds
# Memory cleared.
# ========================================
# Testing model with pruning amount 24.00%
# Pruning Amount: 24.00%
# Model size: 197.13 MB
# Final accuracy: 37.81%
# Compute time: 0.89490 seconds
# Memory cleared.
# ========================================
# Testing model with pruning amount 24.50%
# Pruning Amount: 24.50%
# Model size: 201.44 MB
# Final accuracy: 35.47%
# Compute time: 0.86938 seconds
# Memory cleared.
# ========================================
# Testing model with pruning amount 25.00%
# Pruning Amount: 25.00%
# Model size: 193.59 MB
# Final accuracy: 42.17%
# Compute time: 0.85203 seconds
# Memory cleared.
# ========================================
# Testing model with pruning amount 25.50%
# Pruning Amount: 25.50%
# Model size: 192.97 MB
# Final accuracy: 37.22%
# Compute time: 0.85166 seconds
# Memory cleared.
# ========================================
# Testing model with pruning amount 26.00%
# Pruning Amount: 26.00%
# Model size: 191.78 MB
# Final accuracy: 33.56%
# Compute time: 0.88693 seconds
# Memory cleared.
# ========================================
# Testing model with pruning amount 26.50%
# Pruning Amount: 26.50%
# Model size: 193.36 MB
# Final accuracy: 30.92%
# Compute time: 0.89580 seconds
# Memory cleared.
# ========================================
# Testing model with pruning amount 27.00%
# Pruning Amount: 27.00%
# Model size: 192.19 MB
# Final accuracy: 33.22%
# Compute time: 0.81989 seconds
# Memory cleared.
# ========================================
# Testing model with pruning amount 27.50%
# Pruning Amount: 27.50%
# Model size: 192.11 MB
# Final accuracy: 28.19%
# Compute time: 0.81968 seconds
# Memory cleared.
# ========================================
# Testing model with pruning amount 28.00%
# Pruning Amount: 28.00%
# Model size: 189.26 MB
# Final accuracy: 35.11%
# Compute time: 0.85909 seconds
# Memory cleared.
# ========================================
# Testing model with pruning amount 28.50%
# Pruning Amount: 28.50%
# Model size: 185.26 MB
# Final accuracy: 30.06%
# Compute time: 0.84672 seconds
# Memory cleared.
# ========================================
# Testing model with pruning amount 29.00%
# Pruning Amount: 29.00%
# Model size: 191.92 MB
# Final accuracy: 34.94%
# Compute time: 0.82563 seconds
# Memory cleared.
# ========================================
# Testing model with pruning amount 29.50%
# Pruning Amount: 29.50%
# Model size: 189.61 MB
# Final accuracy: 25.94%
# Compute time: 0.80606 seconds
# Memory cleared.
# ========================================
# Testing model with pruning amount 3.00%
# Pruning Amount: 3.00%
# Model size: 229.71 MB
# Final accuracy: 54.44%
# Compute time: 0.97774 seconds
# Memory cleared.
# ========================================
# Testing model with pruning amount 3.50%
# Pruning Amount: 3.50%
# Model size: 227.41 MB
# Final accuracy: 60.53%
# Compute time: 0.96260 seconds
# Memory cleared.
# ========================================
# Testing model with pruning amount 30.00%
# Pruning Amount: 30.00%
# Model size: 190.65 MB
# Final accuracy: 35.28%
# Compute time: 0.82104 seconds
# Memory cleared.
# ========================================
# Testing model with pruning amount 30.50%
# Pruning Amount: 30.50%
# Model size: 188.30 MB
# Final accuracy: 29.58%
# Compute time: 0.80750 seconds
# Memory cleared.
# ========================================
# Testing model with pruning amount 31.00%
# Pruning Amount: 31.00%
# Model size: 186.58 MB
# Final accuracy: 35.78%
# Compute time: 0.82076 seconds
# Memory cleared.
# ========================================
# Testing model with pruning amount 31.50%
# Pruning Amount: 31.50%
# Model size: 189.28 MB
# Final accuracy: 25.64%
# Compute time: 0.80176 seconds
# Memory cleared.
# ========================================
# Testing model with pruning amount 32.00%
# Pruning Amount: 32.00%
# Model size: 187.01 MB
# Final accuracy: 32.83%
# Compute time: 0.81063 seconds
# Memory cleared.
# ========================================
# Testing model with pruning amount 32.50%
# Pruning Amount: 32.50%
# Model size: 185.27 MB
# Final accuracy: 26.92%
# Compute time: 0.80333 seconds
# Memory cleared.
# ========================================
# Testing model with pruning amount 33.00%
# Pruning Amount: 33.00%
# Model size: 184.65 MB
# Final accuracy: 27.53%
# Compute time: 0.80022 seconds
# Memory cleared.
# ========================================
# Testing model with pruning amount 33.50%
# Pruning Amount: 33.50%
# Model size: 189.05 MB
# Final accuracy: 26.75%
# Compute time: 0.78186 seconds
# Memory cleared.
# ========================================
# Testing model with pruning amount 34.00%
# Pruning Amount: 34.00%
# Model size: 183.41 MB
# Final accuracy: 32.08%
# Compute time: 0.81053 seconds
# Memory cleared.
# ========================================
# Testing model with pruning amount 34.50%
# Pruning Amount: 34.50%
# Model size: 184.41 MB
# Final accuracy: 25.14%
# Compute time: 0.77157 seconds
# Memory cleared.
# ========================================
# Testing model with pruning amount 35.00%
# Pruning Amount: 35.00%
# Model size: 176.56 MB
# Final accuracy: 27.25%
# Compute time: 0.76469 seconds
# Memory cleared.
# ========================================
# Testing model with pruning amount 35.50%
# Pruning Amount: 35.50%
# Model size: 175.37 MB
# Final accuracy: 20.39%
# Compute time: 0.76930 seconds
# Memory cleared.
# ========================================
# Testing model with pruning amount 36.00%
# Pruning Amount: 36.00%
# Model size: 184.25 MB
# Final accuracy: 28.83%
# Compute time: 0.80164 seconds
# Memory cleared.
# ========================================
# Testing model with pruning amount 36.50%
# Pruning Amount: 36.50%
# Model size: 176.37 MB
# Final accuracy: 27.19%
# Compute time: 0.77840 seconds
# Memory cleared.
# ========================================
# Testing model with pruning amount 37.00%
# Pruning Amount: 37.00%
# Model size: 178.46 MB
# Final accuracy: 25.67%
# Compute time: 0.77083 seconds
# Memory cleared.
# ========================================
# Testing model with pruning amount 37.50%
# Pruning Amount: 37.50%
# Model size: 178.48 MB
# Final accuracy: 21.22%
# Compute time: 0.75103 seconds
# Memory cleared.
# ========================================
# Testing model with pruning amount 38.00%
# Pruning Amount: 38.00%
# Model size: 175.61 MB
# Final accuracy: 24.08%
# Compute time: 0.75632 seconds
# Memory cleared.
# ========================================
# Testing model with pruning amount 38.50%
# Pruning Amount: 38.50%
# Model size: 174.99 MB
# Final accuracy: 23.47%
# Compute time: 0.76744 seconds
# Memory cleared.
# ========================================
# Testing model with pruning amount 39.00%
# Pruning Amount: 39.00%
# Model size: 175.47 MB
# Final accuracy: 22.06%
# Compute time: 0.73677 seconds
# Memory cleared.
# ========================================
# Testing model with pruning amount 39.50%
# Pruning Amount: 39.50%
# Model size: 177.62 MB
# Final accuracy: 22.97%
# Compute time: 0.75178 seconds
# Memory cleared.
# ========================================
# Testing model with pruning amount 4.00%
# Pruning Amount: 4.00%
# Model size: 226.73 MB
# Final accuracy: 55.33%
# Compute time: 0.95930 seconds
# Memory cleared.
# ========================================
# Testing model with pruning amount 4.50%
# Pruning Amount: 4.50%
# Model size: 229.45 MB
# Final accuracy: 56.00%
# Compute time: 0.96346 seconds
# Memory cleared.
# ========================================
# Testing model with pruning amount 40.00%
# Pruning Amount: 40.00%
# Model size: 175.95 MB
# Final accuracy: 27.19%
# Compute time: 0.76328 seconds
# Memory cleared.
# ========================================
# Testing model with pruning amount 40.50%
# Pruning Amount: 40.50%
# Model size: 174.20 MB
# Final accuracy: 21.14%
# Compute time: 0.78077 seconds
# Memory cleared.
# ========================================
# Testing model with pruning amount 41.00%
# Pruning Amount: 41.00%
# Model size: 178.01 MB
# Final accuracy: 18.86%
# Compute time: 0.73505 seconds
# Memory cleared.
# ========================================
# Testing model with pruning amount 41.50%
# Pruning Amount: 41.50%
# Model size: 168.48 MB
# Final accuracy: 19.89%
# Compute time: 0.73583 seconds
# Memory cleared.
# ========================================
# Testing model with pruning amount 42.00%
# Pruning Amount: 42.00%
# Model size: 171.24 MB
# Final accuracy: 19.83%
# Compute time: 0.75513 seconds
# Memory cleared.
# ========================================
# Testing model with pruning amount 42.50%
# Pruning Amount: 42.50%
# Model size: 172.26 MB
# Final accuracy: 20.67%
# Compute time: 0.73883 seconds
# Memory cleared.
# ========================================
# Testing model with pruning amount 43.00%
# Pruning Amount: 43.00%
# Model size: 161.64 MB
# Final accuracy: 17.61%
# Compute time: 0.73458 seconds
# Memory cleared.
# ========================================
# Testing model with pruning amount 43.50%
# Pruning Amount: 43.50%
# Model size: 170.48 MB
# Final accuracy: 20.53%
# Compute time: 0.75088 seconds
# Memory cleared.
# ========================================
# Testing model with pruning amount 44.00%
# Pruning Amount: 44.00%
# Model size: 170.98 MB
# Final accuracy: 15.03%
# Compute time: 0.69072 seconds
# Memory cleared.
# ========================================
# Testing model with pruning amount 44.50%
# Pruning Amount: 44.50%
# Model size: 165.89 MB
# Final accuracy: 21.53%
# Compute time: 0.73331 seconds
# Memory cleared.
# ========================================
# Testing model with pruning amount 45.00%
# Pruning Amount: 45.00%
# Model size: 160.82 MB
# Final accuracy: 17.78%
# Compute time: 0.73449 seconds
# Memory cleared.
# ========================================
# Testing model with pruning amount 45.50%
# Pruning Amount: 45.50%
# Model size: 168.02 MB
# Final accuracy: 19.56%
# Compute time: 0.75040 seconds
# Memory cleared.
# ========================================
# Testing model with pruning amount 46.00%
# Pruning Amount: 46.00%
# Model size: 154.55 MB
# Final accuracy: 14.44%
# Compute time: 0.70702 seconds
# Memory cleared.
# ========================================
# Testing model with pruning amount 46.50%
# Pruning Amount: 46.50%
# Model size: 166.77 MB
# Final accuracy: 15.67%
# Compute time: 0.71328 seconds
# Memory cleared.
# ========================================
# Testing model with pruning amount 47.00%
# Pruning Amount: 47.00%
# Model size: 161.73 MB
# Final accuracy: 16.33%
# Compute time: 0.74084 seconds
# Memory cleared.
# ========================================
# Testing model with pruning amount 47.50%
# Pruning Amount: 47.50%
# Model size: 161.11 MB
# Final accuracy: 18.69%
# Compute time: 0.74355 seconds
# Memory cleared.
# ========================================
# Testing model with pruning amount 48.00%
# Pruning Amount: 48.00%
# Model size: 158.82 MB
# Final accuracy: 11.69%
# Compute time: 0.70810 seconds
# Memory cleared.
# ========================================
# Testing model with pruning amount 48.50%
# Pruning Amount: 48.50%
# Model size: 164.34 MB
# Final accuracy: 13.08%
# Compute time: 0.71504 seconds
# Memory cleared.
# ========================================
# Testing model with pruning amount 49.00%
# Pruning Amount: 49.00%
# Model size: 154.22 MB
# Final accuracy: 13.53%
# Compute time: 0.71195 seconds
# Memory cleared.
# ========================================
# Testing model with pruning amount 49.50%
# Pruning Amount: 49.50%
# Model size: 162.55 MB
# Final accuracy: 15.50%
# Compute time: 0.70006 seconds
# Memory cleared.
# ========================================
# Testing model with pruning amount 5.00%
# Pruning Amount: 5.00%
# Model size: 225.98 MB
# Final accuracy: 60.31%
# Compute time: 0.99041 seconds
# Memory cleared.
# ========================================
# Testing model with pruning amount 5.50%
# Pruning Amount: 5.50%
# Model size: 226.44 MB
# Final accuracy: 54.75%
# Compute time: 0.96297 seconds
# Memory cleared.
# ========================================
# Testing model with pruning amount 50.00%
# Pruning Amount: 50.00%
# Model size: 161.39 MB
# Final accuracy: 12.14%
# Compute time: 0.70364 seconds
# Memory cleared.
# ========================================
# Testing model with pruning amount 50.50%
# Pruning Amount: 50.50%
# Model size: 163.04 MB
# Final accuracy: 14.94%
# Compute time: 0.69263 seconds
# Memory cleared.
# ========================================
# Testing model with pruning amount 51.00%
# Pruning Amount: 51.00%
# Model size: 152.91 MB
# Final accuracy: 10.25%
# Compute time: 0.70935 seconds
# Memory cleared.
# ========================================
# Testing model with pruning amount 51.50%
# Pruning Amount: 51.50%
# Model size: 154.54 MB
# Final accuracy: 11.92%
# Compute time: 0.73782 seconds
# Memory cleared.
# ========================================
# Testing model with pruning amount 52.00%
# Pruning Amount: 52.00%
# Model size: 152.81 MB
# Final accuracy: 11.39%
# Compute time: 0.69230 seconds
# Memory cleared.
# ========================================
# Testing model with pruning amount 52.50%
# Pruning Amount: 52.50%
# Model size: 160.58 MB
# Final accuracy: 7.75%
# Compute time: 0.68159 seconds
# Memory cleared.
# ========================================
# Testing model with pruning amount 53.00%
# Pruning Amount: 53.00%
# Model size: 149.37 MB
# Final accuracy: 13.92%
# Compute time: 0.69768 seconds
# Memory cleared.
# ========================================
# Testing model with pruning amount 53.50%
# Pruning Amount: 53.50%
# Model size: 150.99 MB
# Final accuracy: 11.31%
# Compute time: 0.68297 seconds
# Memory cleared.
# ========================================
# Testing model with pruning amount 54.00%
# Pruning Amount: 54.00%
# Model size: 158.15 MB
# Final accuracy: 8.03%
# Compute time: 0.65570 seconds
# Memory cleared.
# ========================================
# Testing model with pruning amount 54.50%
# Pruning Amount: 54.50%
# Model size: 151.43 MB
# Final accuracy: 9.19%
# Compute time: 0.66848 seconds
# Memory cleared.
# ========================================
# Testing model with pruning amount 55.00%
# Pruning Amount: 55.00%
# Model size: 149.17 MB
# Final accuracy: 8.33%
# Compute time: 0.67775 seconds
# Memory cleared.
# ========================================
# Testing model with pruning amount 55.50%
# Pruning Amount: 55.50%
# Model size: 144.66 MB
# Final accuracy: 9.25%
# Compute time: 0.68286 seconds
# Memory cleared.
# ========================================
# Testing model with pruning amount 56.00%
# Pruning Amount: 56.00%
# Model size: 151.86 MB
# Final accuracy: 7.64%
# Compute time: 0.67967 seconds
# Memory cleared.
# ========================================
# Testing model with pruning amount 56.50%
# Pruning Amount: 56.50%
# Model size: 153.47 MB
# Final accuracy: 7.86%
# Compute time: 0.69866 seconds
# Memory cleared.
# ========================================
# Testing model with pruning amount 57.00%
# Pruning Amount: 57.00%
# Model size: 141.71 MB
# Final accuracy: 7.19%
# Compute time: 0.65674 seconds
# Memory cleared.
# ========================================
# Testing model with pruning amount 57.50%
# Pruning Amount: 57.50%
# Model size: 147.24 MB
# Final accuracy: 8.25%
# Compute time: 0.70604 seconds
# Memory cleared.
# ========================================
# Testing model with pruning amount 58.00%
# Pruning Amount: 58.00%
# Model size: 146.64 MB
# Final accuracy: 5.31%
# Compute time: 0.66339 seconds
# Memory cleared.
# ========================================
# Testing model with pruning amount 58.50%
# Pruning Amount: 58.50%
# Model size: 141.01 MB
# Final accuracy: 4.08%
# Compute time: 0.66113 seconds
# Memory cleared.
# ========================================
# Testing model with pruning amount 59.00%
# Pruning Amount: 59.00%
# Model size: 144.31 MB
# Final accuracy: 5.83%
# Compute time: 0.65114 seconds
# Memory cleared.
# ========================================
# Testing model with pruning amount 59.50%
# Pruning Amount: 59.50%
# Model size: 145.96 MB
# Final accuracy: 5.53%
# Compute time: 0.66251 seconds
# Memory cleared.
# ========================================
# Testing model with pruning amount 6.00%
# Pruning Amount: 6.00%
# Model size: 225.25 MB
# Final accuracy: 48.69%
# Compute time: 0.94688 seconds
# Memory cleared.
# ========================================
# Testing model with pruning amount 6.50%
# Pruning Amount: 6.50%
# Model size: 221.82 MB
# Final accuracy: 56.61%
# Compute time: 0.92289 seconds
# Memory cleared.
# ========================================
# Testing model with pruning amount 7.00%
# Pruning Amount: 7.00%
# Model size: 225.09 MB
# Final accuracy: 56.97%
# Compute time: 0.92037 seconds
# Memory cleared.
# ========================================
# Testing model with pruning amount 7.50%
# Pruning Amount: 7.50%
# Model size: 219.40 MB
# Final accuracy: 47.53%
# Compute time: 0.93216 seconds
# Memory cleared.
# ========================================
# Testing model with pruning amount 8.00%
# Pruning Amount: 8.00%
# Model size: 223.18 MB
# Final accuracy: 50.50%
# Compute time: 0.92029 seconds
# Memory cleared.
# ========================================
# Testing model with pruning amount 8.50%
# Pruning Amount: 8.50%
# Model size: 218.69 MB
# Final accuracy: 52.83%
# Compute time: 0.91822 seconds
# Memory cleared.
# ========================================
# Testing model with pruning amount 9.00%
# Pruning Amount: 9.00%
# Model size: 218.03 MB
# Final accuracy: 52.14%
# Compute time: 0.93367 seconds
# Memory cleared.
# ========================================
# Testing model with pruning amount 9.50%
# Pruning Amount: 9.50%
# Model size: 220.72 MB
# Final accuracy: 49.03%
# Compute time: 0.93078 seconds
# Memory cleared.
# ========================================
