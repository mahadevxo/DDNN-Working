# %%
from Rewards import Reward

# %%
MIN_ACC = 60.0
MAX_SIZE = 300.0

# %%
reward = Reward(
    min_accuracy=MIN_ACC,
    max_model_size=MAX_SIZE,
    x=0.9, y=1.0, z=1.0
)

# %%
reward.plot_rewards()
